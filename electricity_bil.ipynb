# %%
#customer information
def customer_info():
    def check_number(phone):
        if phone.isdigit() and len(phone) == 11:
            return True
        else:
            print("Invalid input. Please enter a number.")
            return False
    def check_email(email):
        if "@" in email and "." in email:
            return True
        else:
            print("Invalid input. Please enter a valid email address.")
            return False
    def check_age(age):
        if age.isdigit() and 0 < int(age):
            return True
        else:
            print("Invalid input. Please enter a valid age.")
            return False
    name = input("Enter your name: ")   
    address = input("Enter your address: ")
    phone = input("Enter your phone number: ")
    while not check_number(phone):
        phone = input("Enter your phone number: ")
    email = input("Enter your email address: ")
    while not check_email(email):
        email = input("Enter your email address: ")
    age = input("Enter your age: ")
    while not check_age(age):
        age = input("Enter your age: ")
    
    print("---------------------------------------------------- Electricity Bill --------------------------------------------------------------")
    
    print("Customer Information:")
    print("Name:", name)
    print("Address:", address)
    print("Phone Number:", phone)
    print("Email Address:", email)
    print("Age:", age)

customer_info()
def calculate_bill():
    def check_units(units):
        if units.isdigit() and int(units) >= 0:
            return True
        else:
            print("Invalid input. Please enter a valid number of units.")
            return False
    def bill_per_unit():
        vat = 0.15
        if units == 0 or units <= 50:
            print("It's Agricutural and regular connection")
            print("Rate per unit: TK 4.53")
            return (units * 4.53) + (vat * units)
        elif units == 51 or units <= 100:
            print("It's Hospital connection")
            print("Rate per unit: TK 6.25")
            return units * 5.25 + (vat * units)
        elif units == 101 or units <= 150:
            print("It's religious and educational institution connection")
            print("Rate per unit: TK 7.50")
            return (units * 7.50) + (vat * units)
        elif units == 151 or units <= 200:
            print("It's small industries connection")
            print("Rate per unit: TK 8.50")
            return (units * 8.50) + (vat * units)
        elif units == 201 or units <= 300:
            print("It's Graments connection")
            print("Rate per unit: TK 9.00")
            return (units * 9.00) + (vat * units)
        elif units == 301 or units <= 400:
            print("It's VIP area connection")
            print("Rate per unit: TK 9.50")
            return (units * 10.50) + (vat * units)
        elif units == 401 or units <= 500:
            print("It's economial connection")
            print("Rate per unit: TK 10.00")
            return (units * 12.00) + (vat * units)
        else:
            print("It's privet-economical connection")
            print("Rate per unit: TK 10.50")
            return (units * 16.50) + (vat * units)
    units = input("Enter the number of units consumed: ")
    while not check_units(units):
        units = input("Enter the number of units consumed: ")
    units = int(units)  # Convert to integer after validation

    
    total_bill = bill_per_unit()
    print("Total Bill Amount: {:.2f} Taka".format(total_bill))
calculate_bill()
def payment_method():
    def check_payment_method(method):
        if method in ["1", "2", "3"]:
            return True
        else:
            print("Invalid input. Please select a valid payment method.")
            return False
    print("Payment Methods:")
    print("1. Bkash")
    print("2. Rocket")
    print("3. Nagad")
    payment_method = input("Select your payment method (1/2/3): ")
    while not check_payment_method(payment_method):
        payment_method = input("Select your payment method (1/2/3): ")
    
    if payment_method == "1":
        print("You have selected Bkash.")
    elif payment_method == "2":
        print("You have selected Rocket.")
    else:
        print("You have selected Nagad.")
payment_method()
def payment
# Out:
# ---------------------------------------------------- Electricity Bill --------------------------------------------------------------
# Customer Information:
# Name: Asif
# Address: Dinajpur
# Phone Number: 01704263004
# Email Address: nuraalasif@gmail.com
# Age: 24
# It's Agricutural and regular connection
# Rate per unit: TK 4.53
# Total Bill Amount: 93.60 Taka
